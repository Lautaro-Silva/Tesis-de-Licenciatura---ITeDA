# %%
# --- Celda 1.1: Importaciones y Carga de Librerías Offline ---
import os
import numpy as np
import pandas as pd
import glob
import ROOT
import time
import traceback
from multiprocessing import Pool, cpu_count
from functools import partial
# Out:
# Welcome to JupyROOT 6.30/04

# %%
# Esta es la parte MÁS IMPORTANTE:
# Asegúrate de que estás corriendo este Jupyter Lab desde una terminal
# donde ANTES hiciste: source /ruta/a/auger/offline/this-auger-offline.sh

AugerOfflineRoot = os.environ.get("AUGEROFFLINEROOT")
if AugerOfflineRoot is None:
    raise EnvironmentError(
        "AUGEROFFLINEROOT no definido. "
        "Reinicia Jupyter Lab desde una terminal donde hayas "
        "hecho: "
        " 'aug_set_version offline 4.0.1-icrc23-prod1-root6' "   
        " 'source /srv/software/amd64/ubuntu/24.04/auger/offline/4.0.1-icrc23-prod1-root6/bin/this-auger-offline.sh'."
    )

print(f"AUGEROFFLINEROOT encontrado en: {AugerOfflineRoot}")

# Cargar las librerías necesarias
print("Cargando librerías de Auger Offline...")
libs_to_load = ["libRecEventKG.so"]
for lib in libs_to_load:
    lib_path = os.path.join(AugerOfflineRoot, "lib", lib)
    if not os.path.exists(lib_path):
        raise FileNotFoundError(f"No se encontró la librería: {lib_path}")
    
    # Usamos gSystem.Load que es más robusto en PyROOT
    status = ROOT.gSystem.Load(lib_path)
    if status < 0:
        raise ImportError(f"Error cargando la librería: {lib_path}")

print("Librerías cargadas correctamente. ¡Listo para trabajar! 🚀")
# Out:
# AUGEROFFLINEROOT encontrado en: /srv/software/amd64/ubuntu/24.04/auger/offline/4.0.1-icrc23-prod1-root6
# Cargando librerías de Auger Offline...
# Librerías cargadas correctamente. ¡Listo para trabajar! 🚀

# %%
# --- Celda 2.1: Funciones Auxiliares y Principales (con nMuones_MC) ---

def getModuleList(counter, sim=True):
    """
    Obtiene la lista de objetos 'Module' (segmentos de detector)
    asociados a un 'Counter' (estación UMD).
    
    Parameters:
    ----------
    counter : ROOT.mevt.Counter
        La estación UMD de la cual extraer los módulos.
    sim : bool, default=True
        Flag para indicar si son datos de simulación.
        - True (Simulación): IDs de módulo son 0, 1, 2...
        - False (Datos Reales): IDs de módulo son 100, 101, 102...
    """
    possibleModules = range(0, 6) if sim else range(100, 116)
    modules = []
    for modId in possibleModules:
        if counter.HasModule(modId):
            modules.append(counter.GetModule(modId))
    return modules

def readADST_surface_v13(fname, is_mc_simulation=True):
    """
    Leer un archivo ADST (1 fila por MÓDULO).
    
    Esta función es el corazón del pipeline de procesamiento. Itera sobre
    cada evento (lluvia) en un archivo ADST y extrae la información
    relevante a nivel de MÓDULO de UMD (el nivel más granular).
    
    Lógica Clave:
    1. Itera sobre el MDEvent (mEvent.CountersBegin()) para encontrar
       TODOS los counters UMD (tanto Infill '4k' como Anillo Denso '90k').
    2. Usa el SDEvent como "diccionario" de geometría para obtener r y phi.
    3. NO filtra por 'IsLowGainSaturated', en su lugar, guarda un flag.
    4. Versión HÍBRIDA (v12) para calcular la posicion:
    
    Combina la lógica original (v7) para el Anillo Denso con la corrección
    de Euler (v10) para el Infill:
    - Si ID es 90k (UMD): Se confía en GetAzimuthSP (Mantiene consistencia con Money Plots).
    - Si ID es Infill/Std: Se fuerza la Rotación de Euler (Arregla el bug de proyección).

    Versión DEBUG: Calcula y guarda 3 definiciones de Phi para comparación para 
                   el infill y mostrar que esta mal el uso del SP en el infill:
                   
    a. Euler (3D Correcto) usando REC
    b. Ground (2D Proyección simple)
    c. SP (Nativo de Auger)
    d. Agrego Euler usando MC

    5. Guarda la señal REC ('nMuones_REC') y la señal MC ('nMuones_MC')
       para cada módulo individual para el UMD.

    6. Para el SD guarda las señal REC + MC: separa la parte EM
       de Muonica para el MC; y la total y Muonica para el REC.

    """
    
    print(f"Iniciando lectura de: {os.path.basename(fname)}")
    
    if not os.path.exists(fname):
        print(f"Advertencia: Archivo no encontrado {fname}")
        return pd.DataFrame() # Retorna DF vacío 

    # --- Inicialización de ROOT ---
    files = ROOT.std.vector('string')()
    files.push_back(fname)

    file1 = ROOT.RecEventFile(files)
    event = ROOT.RecEvent()
    geo = ROOT.DetectorGeometry()
    
    file1.ReadDetectorGeometry(geo) # Ignoramos fallos (Warnings de TStreamerInfo)
    file1.SetBuffers(event)

    data = []
    event_count = 0
    start_time = time.time()

    # --- COMIENZA EL BUCLE DE EVENTOS ---
    while file1.ReadNextEvent() == ROOT.RecEventFile.eSuccess:
        event_count += 1
        if event_count % 500 == 0:
            print(f"... procesados {event_count} eventos.")
        
        # --- Info Global del Evento (Lluvia) ---
        event_id_lluvia = event.GetEventId()
        
        # Simulación
        MCShower = event.GetGenShower()
        mc_energy = MCShower.GetEnergy()
        logE_MC = np.log10(mc_energy) if mc_energy > 0 else np.nan

        # [MODIFICACIÓN v13] Guardamos ángulos MC en Grados y RADIANES
        mc_theta_rad = MCShower.GetZenith()
        mc_phi_rad = MCShower.GetAzimuth()
        
        theta_MC = MCShower.GetZenith() * 180.0 / np.pi
        phi_MC = MCShower.GetAzimuth() * 180.0 / np.pi
        primary = MCShower.GetShortPrimaryName()
        
        # Reconstrucción
        sEvent = event.GetSDEvent()
        sShower = sEvent.GetSdRecShower()
        rec_energy = sShower.GetEnergy()
        logE_REC = np.log10(rec_energy) if rec_energy > 0 else np.nan
        
        # Ángulos
        theta_REC_deg = sShower.GetZenith() * 180.0 / np.pi
        phi_REC_deg = sShower.GetAzimuth() * 180.0 / np.pi

        rec_theta_rad = sShower.GetZenith()
        rec_phi_rad = sShower.GetAzimuth()
        
        # Core (Usamos el Core Reconstruido como pivote para ambos casos)
        pos_core = sShower.GetCoreSiteCS()
    
        # --- Bucle sobre los COUNTERS ---
        mEvent = event.GetMDEvent()
        counterIterator = mEvent.CountersBegin()
        countersEnd = mEvent.CountersEnd()
        
        while counterIterator != countersEnd:
            
            counter = counterIterator.__deref__() # Objeto Counter (estación)
            counterId = counter.GetId()           
            sdId = counter.GetSdPartnerId()    

            # Buscamos la estación de superficie (SD) asociada
            sdStation = sEvent.GetStationById(sdId) if sEvent.HasStation(sdId) else None
            
            # --- Corte de Calidad 1: Geometría ---
            # Si no hay sdStation, no podemos calcular r_core ni phi_plane.
            # Ese counter no sirve para el análisis de asimetría.
            if sdStation is None:
                counterIterator += 1 # Avanzamos al siguiente counter
                continue 

            # --- Corte de Calidad 2: Saturación (Corte Diferido) ---
            # Guardamos el flag, como discutimos, en lugar de filtrar.
            is_sd_saturated = sdStation.IsLowGainSaturated()
            
            # Datos básicos de la reconstruccion
            sdSignal = sdStation.GetTotalSignal()
            sdSignal_err = sdStation.GetTotalSignalError()
            sdMuonSignal = sdStation.GetMuonSignal() # Suele ser 0 en Reco estándar

            # --- CÁLCULO DE COMPONENTES MC (CONTEO DE PARTICULAS) ---
            mc_sd_n_muon = np.nan
            mc_sd_n_em = np.nan # Suma de electrones + fotones
            
            if hasattr(sEvent, "HasSimStation") and sEvent.HasSimStation(sdId):
                simStation = sEvent.GetSimStationById(sdId)
                
                # Usamos los métodos que el Hunter encontró como NO NULOS
                if hasattr(simStation, "GetNumberOfMuons"):
                    mc_sd_n_muon = float(simStation.GetNumberOfMuons())
                
                # Para la parte EM sumamos electrones y fotones
                n_e = 0.0
                n_gamma = 0.0
                if hasattr(simStation, "GetNumberOfElectrons"):
                    n_e = float(simStation.GetNumberOfElectrons())
                if hasattr(simStation, "GetNumberOfPhotons"):
                    n_gamma = float(simStation.GetNumberOfPhotons())
                
                mc_sd_n_em = n_e + n_gamma

                
            r_core_err = sdStation.GetSPDistanceError() 


            # ==================================================================
            # BIFURCACIÓN CORRECTA (Lógica Adaptada a IDs Mixtos) - Lazy Loading 
            # ==================================================================

            # Definimos si es Infill (físico o lógico) para saber qué camino tomar
            # Infill Físico: ~4000 a 6000. Infill Lógico: ~104000 a 106000.
            # Anillo Denso: 90000 a 99999.
            
            is_infill = (sdId >= 100000) or (2000 < sdId < 90000)
            is_anillo_denso = (90000 <= sdId < 100000)

            # --- 1. PHI NATIVO (SP) ---
            # Para Infill (cualquiera de los dos), SP suele ser absoluto (Norte), hay que restar la lluvia.
            # Para Denso (90k), SP ya es relativo.
            val_sp = sdStation.GetAzimuthSP()
            if is_infill:
                phi_sp = val_sp - rec_phi_rad
            else:
                phi_sp = val_sp
            phi_plane_sp = (phi_sp + 2*np.pi) % (2*np.pi)

            # Inicialización de variables geométricas
            phi_plane_ground = np.nan
            phi_plane_euler = np.nan
            
            # [NUEVO v13] Variables MC
            phi_plane_euler_MC = np.nan
            
            if is_anillo_denso:
                # --- CASO A: ANILLO DENSO (UMD 90k) ---
                # NO PEDIMOS geo.GetStationPosition() AQUÍ. Usamos directamente 
                # las variables pre-calculadas del SP al funcionar bien y ser las correctas.
                
                phi_rel = sdStation.GetAzimuthSP()
                r_final = sdStation.GetSPDistance()
                
                x_plane = r_final * np.cos(phi_rel)
                y_plane = r_final * np.sin(phi_rel)
                phi_plane_final = (phi_rel + 2 * np.pi) % (2 * np.pi)
                
                # Definimos una posición dummy
                pos_station = None 
                
            else:
                # --- CASO B: INFILL (4k o 104k) / ESTÁNDAR ---
                # AHORA SÍ pedimos la posición, porque la necesitamos para Euler.
                try:
                    pos_station = geo.GetStationPosition(sdId)
                except:
                    # Si falla con el ID que tenemos, probamos el "otro" por las dudas (parche de seguridad)
                    try:
                        alt_id = sdId + 100000 if sdId < 90000 else sdId - 100000
                        pos_station = geo.GetStationPosition(alt_id)
                    except:
                        counterIterator += 1
                        # print(f'Basura: ID {sdId} no encontrado en Geometría')
                        continue
                
                dx = pos_station.X() - pos_core.X()
                dy = pos_station.Y() - pos_core.Y()
                dz = pos_station.Z() - pos_core.Z()

                # --- 2. PHI GROUND (2D) ---
                phi_g_abs = np.arctan2(dy, dx)
                phi_plane_ground = (phi_g_abs - rec_phi_rad + 2*np.pi) % (2*np.pi)

                # --- 3. PHI EULER (3D - RECONSTRUCTED) ---
                v_rel = ROOT.TVector3(dx, dy, dz)
                v_rel.RotateZ(-rec_phi_rad)
                v_rel.RotateY(-rec_theta_rad)
                phi_e_raw = np.arctan2(v_rel.Y(), v_rel.X())
                
                # APLICAMOS TU ROTACIÓN +180 (Solo a Euler para testear)
                phi_plane_euler = (phi_e_raw + np.pi + 2*np.pi) % (2*np.pi)
                
                r_final = np.sqrt(v_rel.X()**2 + v_rel.Y()**2)
                x_plane = v_rel.X() # Ojo: esto es en el plano rotado
                y_plane = v_rel.Y()
                
                # --- [NUEVO v13] 4. PHI EULER (3D - MC TRUTH) ---
                # Usamos dx, dy, dz (posición física real) pero rotamos usando
                # los ángulos VERDADEROS de la lluvia (MC).
                v_rel_mc = ROOT.TVector3(dx, dy, dz)
                v_rel_mc.RotateZ(-mc_phi_rad)   # <--- Ángulo MC
                v_rel_mc.RotateY(-mc_theta_rad) # <--- Ángulo MC
                phi_e_mc_raw = np.arctan2(v_rel_mc.Y(), v_rel_mc.X())
                
                # Aplicamos el mismo parche +180 para comparar peras con peras
                phi_plane_euler_MC = (phi_e_mc_raw + np.pi + 2*np.pi) % (2*np.pi)
                
            # --- INFO MC ---
            simCounter = mEvent.GetSimCounter(counterId)
            if simCounter is None:
                counterIterator += 1
                continue
                
            # --- Bucle sobre los MÓDULOS (Segmentos) ---
            modules = getModuleList(counter, sim=is_mc_simulation)
            for module in modules:

                # --- Señal Reconstruida (REC) ---
                nMuones_REC = module.GetNumberOfEstimatedMuons()
                moduleId = module.GetId()

                # --- Estado del Módulo (Flag de Calidad) ---
                if module.IsCandidate(): status = "candidate"
                elif module.IsSaturated(): status = "saturated"
                elif module.IsRejected(): status = "rejected"
                elif module.IsSilent(): status = "silent"
                else: status = "undefined"

                # --- ❗️ CÁLCULO DE MUONES MC (Verdad) ❗️ ---
                # Inspo Carmi: Iteramos por los 2 canales (scintillators)
                # de este módulo y sumamos los muones MC "inyectados".
                nMuones_MC_module = 0.0
                channelIterator = module.ChannelsBegin()
                channelsEnd = module.ChannelsEnd()
                 
                # Le preguntamos al 'simCounter' por el 'simScintillator'
                # que corresponde a este 'moduleId' y 'channelId'
                while channelIterator != channelsEnd:
                    channel = channelIterator.__deref__()
                    channelId = channel.GetId()
                    
                    if simCounter.HasSimScintillatorByChannel(moduleId, channelId):
                        mdSimScintillator = simCounter.GetSimScintillatorByChannelId(moduleId, channelId)
                        nMuones_MC_module += mdSimScintillator.GetNumberOfInjectedMuons()
                        
                    channelIterator += 1
                # --- ❗️ FIN DEL CÁLCULO MC ❗️ ---

                data.append({
                    "event_id": event_id_lluvia,
                    
                    # Info MC
                    "logE_MC": logE_MC, "theta_MC": theta_MC, "phi_MC": phi_MC, "primary": primary,
                    
                    # Info REC
                    "logE_REC": logE_REC, "theta_REC": theta_REC_deg, "phi_REC": phi_REC_deg,
                    
                    # Info Módulo/Counter
                    "counterId": counterId,
                    "moduleId": moduleId,
                    "nMuones_REC": nMuones_REC,
                    "nMuones_MC": nMuones_MC_module,
                    "module_status": status,      
                    "is_sd_saturated": is_sd_saturated,

                    # Info de Geometría (plano de lluvia)
                    "x_plane": x_plane,
                    "y_plane": y_plane,
                    "phi_plane_sp": phi_plane_sp,
                    "phi_plane_ground": phi_plane_ground,
                    "phi_plane_euler": phi_plane_euler,

                    # [NUEVO v13] Guardamos la geometría MC pura
                    "phi_plane_euler_MC": phi_plane_euler_MC,
                    
                    "r_core": r_final,
                    "r_core_err": r_core_err,     

                    # Señal SD (REC en VEM + MC Truth en Conteo)
                    "sdId": sdId,
                    "sdSignal_REC": sdSignal,           # Reconstruido (VEM)
                    "sd_nMuons_MC": mc_sd_n_muon,       # Verdad MC (Conteo)
                    "sd_nEM_MC": mc_sd_n_em,            # Verdad MC (Conteo)
                    "sdSignal_err": sdSignal_err,
                    "sdMuonSignal_REC": sdMuonSignal # REC Muon
                })


            counterIterator += 1 # Avanzamos al siguiente counter
                
    end_time = time.time()
    elapsed = end_time - start_time
    
    print(f"Lectura completa. Total de eventos leídos: {event_count}")
    print(f"Tiempo total de lectura: {elapsed:.2f} segundos.")
    print(f"Total de 'MÓDULOS' (filas) extraídos: {len(data)}")

    df = pd.DataFrame(data)
    return df

# %%
# -----------------------------------------------------------------
# FUNCIÓN "TRABAJADORA"
# ❗️ 2. AHORA ACEPTA 'output_dir' COMO ARGUMENTO
# -----------------------------------------------------------------
def process_file_wrapper(root_fpath, output_dir):
    # 1. Definir rutas
    filename = os.path.basename(root_fpath)
    output_filename = filename.replace(".root", ".parquet")
    output_path = os.path.join(output_dir, output_filename)
    
    # 2. Evitar reprocesar
    if os.path.exists(output_path):
        return f"INFO: El archivo ya existe, saltando: {output_filename}"

    # 3. Imprimir estado
    print(f"► [Iniciando]: {filename}")
    
    try:
        # ----- INICIO DEL TRABAJO -----
        start_file_time = time.time()

        # IMPORTANTE CAMBIAR EL NOMBRE EN FUNCION DE LA VERSION DE LA FUNCION
        df = readADST_surface_v12(root_fpath) 
        
        if df.empty:
            return f"INFO: Archivo vacío o sin datos UMD. Saltando: {filename}"

        # 2. Extraer metadatos del nombre de archivo
        try:
            parts = filename.split('_')
            df["model_mc"] = parts[0]
            df["e_min_mc"] = float(parts[1]) / 10.0
            df["e_max_mc"] = float(parts[2]) / 10.0
            df["primary_name_mc"] = parts[3]
            run_part = parts[-1].replace('.root', '')
            df["run_number"] = int(run_part.replace('Run', ''))
        except Exception as e_parse:
            print(f"  Advertencia: No se pudo parsear metadata en {filename}: {e_parse}")

        # 3. Guardar en Parquet
        df.to_parquet(
            output_path,
            compression="snappy",
            index=False
        )
        
        # 4. Liberar memoria
        del df
        
        end_file_time = time.time()
        elapsed = end_file_time - start_file_time
        return f"✔ [Éxito]: {filename} -> {output_filename} ({elapsed:.2f}s)"

        # ----- FIN DEL TRABAJO -----

    except Exception as e:
        # Si algo falla, retornamos el string de error
        return f"❌ [ERROR] en {filename}: {e}\n{traceback.format_exc()}"

# %% [markdown]
# # Paralelizacion -> QGS-Helio-17.5-18eV

# %%
# -----------------------------------------------------------------
# SCRIPT PRINCIPAL
# -----------------------------------------------------------------

n_workers = 8  # Ajustar como sea necesario



print(f"--- INICIANDO PROCESO PARALELO ({n_workers} Workers) ---")
start_total_time = time.time()

# --- 1. Configuración de Rutas ---
base_path = "/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium"
output_dir = "/home/lsilva/Github/ADST_Alexey_module_v8/parquet_qgs_helio_17/"

os.makedirs(output_dir, exist_ok=True)
print(f"Buscando archivos en: {base_path}")
print(f"Los archivos .parquet se guardarán en: {output_dir}")

# --- 2. Encontrar todos los archivos ---
all_root_files = glob.glob(os.path.join(base_path, "*.root"))
all_root_files.sort()

if not all_root_files:
    print(f"¡Error! No se encontraron archivos .root en: {base_path}")
else:
    print(f"Encontrados {len(all_root_files)} archivos .root para procesar.")
    
    # --- 3. Bucle de Procesamiento Paralelo ---
    print(f"Iniciando Pool con {n_workers} trabajadores...")

    # CREAMOS LA FUNCIÓN "PARCIAL" 
    # "Congelamos" el argumento 'output_dir' de nuestra función wrapper
    process_func = partial(process_file_wrapper, output_dir=output_dir)

    with Pool(processes=n_workers) as pool:
        
        # pool.map() distribuye la lista 'all_root_files'
        # entre los 4 trabajadores y aplica la función 'process_file_wrapper'
        # results' será una lista con los strings de "Éxito" o "ERROR"
        results = pool.map(process_func, all_root_files)
    
    print("\n\n--- Proceso Paralelo Completado ---")

    # --- 4. Resumen Final ---
    exitos = 0
    errores = 0
    
    # Imprimimos todos los mensajes de resultado
    for res in results:
        print(res)
        if "✔ [Éxito]" in res:
            exitos += 1
        elif "❌ [ERROR]" in res:
            errores += 1

    end_total_time = time.time()
    print("\n--- Resumen de la Tanda ---")
    print(f"Tiempo total: {(end_total_time - start_total_time) / 60:.2f} minutos")
    print(f"Total de archivos: {len(all_root_files)}")
    print(f"Éxitos: {exitos}")
    print(f"Errores: {errores}")
    print(f"¡Listo! Tus archivos .parquet están en: {output_dir}")
# Out:
# --- INICIANDO PROCESO PARALELO (8 Workers) ---
# Buscando archivos en: /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium
# Los archivos .parquet se guardarán en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_qgs_helio_17/
# Encontrados 20 archivos .root para procesar.
# Iniciando Pool con 8 trabajadores...
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.rootIniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.rootIniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.rootIniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#
#
#
#
#
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.... procesados 500 eventos.
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1210
# Tiempo total de lectura: 604.79 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80127
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Lectura completa. Total de eventos leídos: 1225
# Tiempo total de lectura: 607.90 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80976
# Lectura completa. Total de eventos leídos: 1217
# Tiempo total de lectura: 609.53 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81048
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Lectura completa. Total de eventos leídos: 1213Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#
# Tiempo total de lectura: 609.79 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80964
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Lectura completa. Total de eventos leídos: 1216
# Tiempo total de lectura: 617.41 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80541
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Lectura completa. Total de eventos leídos: 1215
# Tiempo total de lectura: 620.19 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81180
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.rootLectura completa. Total de eventos leídos: 1215
#
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.rootTiempo total de lectura: 621.90 segundos.
#
# Total de 'MÓDULOS' (filas) extraídos: 81039
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Lectura completa. Total de eventos leídos: 1221
# Tiempo total de lectura: 628.67 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81282
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1211
# Tiempo total de lectura: 601.98 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80421
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Lectura completa. Total de eventos leídos: 1216
# Tiempo total de lectura: 589.32 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79947
# Lectura completa. Total de eventos leídos: 1215
# Tiempo total de lectura: 600.54 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80139
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Lectura completa. Total de eventos leídos: 1212
# Tiempo total de lectura: 602.24 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79716
# ► [Iniciando]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Iniciando lectura de: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Lectura completa. Total de eventos leídos: 1209
# Tiempo total de lectura: 606.08 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80076
# Lectura completa. Total de eventos leídos: 1215
# Tiempo total de lectura: 607.53 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80343
# Lectura completa. Total de eventos leídos: 1207
# Tiempo total de lectura: 602.93 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 78885
# Lectura completa. Total de eventos leídos: 1212
# Tiempo total de lectura: 610.69 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79986
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1218
# Tiempo total de lectura: 390.13 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79515
# Lectura completa. Total de eventos leídos: 1215
# Tiempo total de lectura: 393.55 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79653
# Lectura completa. Total de eventos leídos: 1215
# Tiempo total de lectura: 397.97 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79878
# Lectura completa. Total de eventos leídos: 1212
# Tiempo total de lectura: 396.88 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79425
#
#
# --- Proceso Paralelo Completado ---
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.parquet (619.98s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.parquet (630.68s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.parquet (639.58s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.parquet (620.52s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.parquet (632.65s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.parquet (627.95s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.parquet (618.51s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.parquet (615.74s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.parquet (603.98s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.parquet (608.19s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.parquet (602.69s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.parquet (604.20s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.parquet (608.87s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.parquet (590.93s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.parquet (612.15s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.parquet (604.38s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.parquet (391.52s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.parquet (394.80s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.parquet (399.23s)
# ✔ [Éxito]: QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root -> QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.parquet (398.16s)
#
# --- Resumen de la Tanda ---
# Tiempo total: 27.06 minutos
# Total de archivos: 20
# Éxitos: 20
# Errores: 0
# ¡Listo! Tus archivos .parquet están en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_qgs_helio_17/
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#   input file   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/QGSIII01/17.5_18.0/helium/QGSIII01_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root

# %% [markdown]
# # Paralelizacion -> Sibyl-Helio-17.5-18eV

# %%
# -----------------------------------------------------------------
# SCRIPT PRINCIPAL
# -----------------------------------------------------------------

n_workers = 8  # Ajustar como sea necesario



print(f"--- INICIANDO PROCESO PARALELO ({n_workers} Workers) ---")
start_total_time = time.time()

# --- 1. Configuración de Rutas ---
base_path = "/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium"
output_dir = "/home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_helio_17/"

os.makedirs(output_dir, exist_ok=True)
print(f"Buscando archivos en: {base_path}")
print(f"Los archivos .parquet se guardarán en: {output_dir}")

# --- 2. Encontrar todos los archivos ---
all_root_files = glob.glob(os.path.join(base_path, "*.root"))
all_root_files.sort()

if not all_root_files:
    print(f"¡Error! No se encontraron archivos .root en: {base_path}")
else:
    print(f"Encontrados {len(all_root_files)} archivos .root para procesar.")

    # --- 3. Bucle de Procesamiento Paralelo ---
    print(f"Iniciando Pool con {n_workers} trabajadores...")
    
    # CREAMOS LA FUNCIÓN "PARCIAL" 
    # "Congelamos" el argumento 'output_dir' de nuestra función wrapper
    process_func = partial(process_file_wrapper, output_dir=output_dir)

    with Pool(processes=n_workers) as pool:
        
        # pool.map() distribuye la lista 'all_root_files'
        # entre los 4 trabajadores y aplica la función 'process_file_wrapper'
        # results' será una lista con los strings de "Éxito" o "ERROR"
        results = pool.map(process_func, all_root_files)
        
    print("\n\n--- Proceso Paralelo Completado ---")

    # --- 4. Resumen Final ---
    exitos = 0
    errores = 0
    
    # Imprimimos todos los mensajes de resultado
    for res in results:
        print(res)
        if "✔ [Éxito]" in res:
            exitos += 1
        elif "❌ [ERROR]" in res:
            errores += 1

    end_total_time = time.time()
    print("\n--- Resumen de la Tanda ---")
    print(f"Tiempo total: {(end_total_time - start_total_time) / 60:.2f} minutos")
    print(f"Total de archivos: {len(all_root_files)}")
    print(f"Éxitos: {exitos}")
    print(f"Errores: {errores}")
    print(f"¡Listo! Tus archivos .parquet están en: {output_dir}")
# Out:
# --- INICIANDO PROCESO PARALELO (8 Workers) ---
# Buscando archivos en: /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium
# Los archivos .parquet se guardarán en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_helio_17/
# Encontrados 20 archivos .root para procesar.
# Iniciando Pool con 8 trabajadores...
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.rootIniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.rootIniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.rootIniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#
#
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#
#
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.... procesados 500 eventos.
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1217
# Tiempo total de lectura: 612.78 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 82101
# Lectura completa. Total de eventos leídos: 1206
# Tiempo total de lectura: 613.03 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80547
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Lectura completa. Total de eventos leídos: 1216
# Tiempo total de lectura: 615.16 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81630
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Lectura completa. Total de eventos leídos: 1223
# Tiempo total de lectura: 617.45 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81909
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Lectura completa. Total de eventos leídos: 1223
# Tiempo total de lectura: 623.30 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81918
# Lectura completa. Total de eventos leídos: 1219
# Tiempo total de lectura: 624.54 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81828
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Lectura completa. Total de eventos leídos: 1214
# Tiempo total de lectura: 632.01 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81783
# Lectura completa. Total de eventos leídos: 1218
# Tiempo total de lectura: 632.73 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81756
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1215
# Tiempo total de lectura: 596.72 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81687
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Lectura completa. Total de eventos leídos: 1210
# Tiempo total de lectura: 599.84 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81462
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Lectura completa. Total de eventos leídos: 1221
# Tiempo total de lectura: 598.47 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81015
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Lectura completa. Total de eventos leídos: 1220
# Tiempo total de lectura: 603.76 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80928
# ► [Iniciando]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Iniciando lectura de: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Lectura completa. Total de eventos leídos: 1213
# Tiempo total de lectura: 599.11 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80916
# Lectura completa. Total de eventos leídos: 1218
# Tiempo total de lectura: 594.99 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80430
# Lectura completa. Total de eventos leídos: 1227
# Tiempo total de lectura: 599.80 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81321
# Lectura completa. Total de eventos leídos: 1221
# Tiempo total de lectura: 611.90 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80586
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1209
# Tiempo total de lectura: 398.42 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79935
# Lectura completa. Total de eventos leídos: 1220
# Tiempo total de lectura: 394.34 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80832
# Lectura completa. Total de eventos leídos: 1213
# Tiempo total de lectura: 398.71 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80247
# Lectura completa. Total de eventos leídos: 1217
# Tiempo total de lectura: 407.36 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80226
#
#
# --- Proceso Paralelo Completado ---
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.parquet (628.09s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.parquet (634.09s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.parquet (643.41s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.parquet (642.82s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.parquet (635.27s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.parquet (625.53s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.parquet (623.28s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.parquet (623.60s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.parquet (598.97s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.parquet (601.83s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.parquet (605.85s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.parquet (600.68s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.parquet (613.74s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.parquet (601.70s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.parquet (601.52s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.parquet (596.60s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.parquet (408.57s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.parquet (399.64s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.parquet (399.96s)
# ✔ [Éxito]: SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root -> SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.parquet (395.52s)
#
# --- Resumen de la Tanda ---
# Tiempo total: 27.19 minutos
# Total de archivos: 20
# Éxitos: 20
# Errores: 0
# ¡Listo! Tus archivos .parquet están en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_helio_17/
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#   input file   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/helium/SIB23e_175_180_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root

# %% [markdown]
# # Paralelizacion -> Sibyl-Hierro-17.5-18eV

# %%
# -----------------------------------------------------------------
# SCRIPT PRINCIPAL
# -----------------------------------------------------------------

n_workers = 8  # Ajustar como sea necesario



print(f"--- INICIANDO PROCESO PARALELO ({n_workers} Workers) ---")
start_total_time = time.time()

# --- 1. Configuración de Rutas ---
base_path = "/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron"
output_dir = "/home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_hierro_17/"

os.makedirs(output_dir, exist_ok=True)
print(f"Buscando archivos en: {base_path}")
print(f"Los archivos .parquet se guardarán en: {output_dir}")

# --- 2. Encontrar todos los archivos ---
all_root_files = glob.glob(os.path.join(base_path, "*.root"))
all_root_files.sort()

if not all_root_files:
    print(f"¡Error! No se encontraron archivos .root en: {base_path}")
else:
    print(f"Encontrados {len(all_root_files)} archivos .root para procesar.")

    # --- 3. Bucle de Procesamiento Paralelo ---
    print(f"Iniciando Pool con {n_workers} trabajadores...")

    # CREAMOS LA FUNCIÓN "PARCIAL" 
    # "Congelamos" el argumento 'output_dir' de nuestra función wrapper
    process_func = partial(process_file_wrapper, output_dir=output_dir)

    with Pool(processes=n_workers) as pool:
        
        # pool.map() distribuye la lista 'all_root_files'
        # entre los 4 trabajadores y aplica la función 'process_file_wrapper'
        # results' será una lista con los strings de "Éxito" o "ERROR"
        results = pool.map(process_func, all_root_files)
    
    print("\n\n--- Proceso Paralelo Completado ---")

    # --- 4. Resumen Final ---
    exitos = 0
    errores = 0
    
    # Imprimimos todos los mensajes de resultado
    for res in results:
        print(res)
        if "✔ [Éxito]" in res:
            exitos += 1
        elif "❌ [ERROR]" in res:
            errores += 1

    end_total_time = time.time()
    print("\n--- Resumen de la Tanda ---")
    print(f"Tiempo total: {(end_total_time - start_total_time) / 60:.2f} minutos")
    print(f"Total de archivos: {len(all_root_files)}")
    print(f"Éxitos: {exitos}")
    print(f"Errores: {errores}")
    print(f"¡Listo! Tus archivos .parquet están en: {output_dir}")
# Out:
# --- INICIANDO PROCESO PARALELO (8 Workers) ---
# Buscando archivos en: /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron
# Los archivos .parquet se guardarán en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_hierro_17/
# Encontrados 20 archivos .root para procesar.
# Iniciando Pool con 8 trabajadores...
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.root► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#
#
#
#
#
#
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.rootIniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.rootIniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.rootIniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.rootIniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#
#
#
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1233
# Tiempo total de lectura: 610.85 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84423
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Lectura completa. Total de eventos leídos: 1227
# Tiempo total de lectura: 615.04 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84639
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Lectura completa. Total de eventos leídos: 1235
# Tiempo total de lectura: 617.18 segundos.Total de 'MÓDULOS' (filas) extraídos: 84708
#
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Lectura completa. Total de eventos leídos: 1232
# Tiempo total de lectura: 621.16 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84603
# Lectura completa. Total de eventos leídos: 1236
# Tiempo total de lectura: 621.51 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83961
# Lectura completa. Total de eventos leídos: 1227
# Tiempo total de lectura: 622.71 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84243
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Lectura completa. Total de eventos leídos: 1233
# Tiempo total de lectura: 626.29 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84738
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Lectura completa. Total de eventos leídos: 1232
# Tiempo total de lectura: 630.56 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84135
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1233
# Tiempo total de lectura: 595.46 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83673
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Lectura completa. Total de eventos leídos: 1233
# Tiempo total de lectura: 606.09 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84351
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Lectura completa. Total de eventos leídos: 1236
# Tiempo total de lectura: 604.36 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84213
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Lectura completa. Total de eventos leídos: 1229
# Tiempo total de lectura: 600.26 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83775
# ► [Iniciando]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Iniciando lectura de: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Lectura completa. Total de eventos leídos: 1239
# Tiempo total de lectura: 602.96 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83574
# Lectura completa. Total de eventos leídos: 1233
# Tiempo total de lectura: 601.73 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83676
# Lectura completa. Total de eventos leídos: 1228
# Tiempo total de lectura: 600.89 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83760
# Lectura completa. Total de eventos leídos: 1237
# Tiempo total de lectura: 611.77 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 84066
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1218
# Tiempo total de lectura: 394.69 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 82710
# Lectura completa. Total de eventos leídos: 1230
# Tiempo total de lectura: 401.03 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83340
# Lectura completa. Total de eventos leídos: 1235
# Tiempo total de lectura: 399.09 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83478
# Lectura completa. Total de eventos leídos: 1223
# Tiempo total de lectura: 409.83 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83172
#
#
# --- Proceso Paralelo Completado ---
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.parquet (633.44s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.parquet (641.20s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.parquet (621.57s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.parquet (631.53s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.parquet (625.53s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.parquet (627.43s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.parquet (637.05s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.parquet (631.82s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run033.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run033.parquet (608.08s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run034.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run034.parquet (606.46s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run080.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run080.parquet (597.35s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run081.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run081.parquet (602.31s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run082.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run082.parquet (605.12s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run083.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run083.parquet (613.35s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run084.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run084.parquet (603.91s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run090.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run090.parquet (602.55s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run091.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run091.parquet (411.54s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run092.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run092.parquet (402.56s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run093.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run093.parquet (400.42s)
# ✔ [Éxito]: SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run094.root -> SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run094.parquet (396.00s)
#
# --- Resumen de la Tanda ---
# Tiempo total: 27.28 minutos
# Total de archivos: 20
# Éxitos: 20
# Errores: 0
# ¡Listo! Tus archivos .parquet están en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_hierro_17/
#   input file   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/iron/SIB23e_175_180_iron_MdSdInfill_CORSIKA78010_FLUKA_Run094.root

# %% [markdown]
# # Paralelizacion -> Sibyl-Oxigeno-17.5-18eV

# %%
# -----------------------------------------------------------------
# SCRIPT PRINCIPAL
# -----------------------------------------------------------------

n_workers = 8  # Ajustar como sea necesario



print(f"--- INICIANDO PROCESO PARALELO ({n_workers} Workers) ---")
start_total_time = time.time()

# --- 1. Configuración de Rutas ---
base_path = "/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen"
output_dir = "/home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_oxigeno_17/"

os.makedirs(output_dir, exist_ok=True)
print(f"Buscando archivos en: {base_path}")
print(f"Los archivos .parquet se guardarán en: {output_dir}")

# --- 2. Encontrar todos los archivos ---
all_root_files = glob.glob(os.path.join(base_path, "*.root"))
all_root_files.sort()

if not all_root_files:
    print(f"¡Error! No se encontraron archivos .root en: {base_path}")
else:
    print(f"Encontrados {len(all_root_files)} archivos .root para procesar.")

    # --- 3. Bucle de Procesamiento Paralelo ---
    print(f"Iniciando Pool con {n_workers} trabajadores...")

    # CREAMOS LA FUNCIÓN "PARCIAL" 
    # "Congelamos" el argumento 'output_dir' de nuestra función wrapper
    process_func = partial(process_file_wrapper, output_dir=output_dir)

    with Pool(processes=n_workers) as pool:
        
        # pool.map() distribuye la lista 'all_root_files'
        # entre los 4 trabajadores y aplica la función 'process_file_wrapper'
        # results' será una lista con los strings de "Éxito" o "ERROR"
        results = pool.map(process_func, all_root_files)
    
    print("\n\n--- Proceso Paralelo Completado ---")

    # --- 4. Resumen Final ---
    exitos = 0
    errores = 0
    
    # Imprimimos todos los mensajes de resultado
    for res in results:
        print(res)
        if "✔ [Éxito]" in res:
            exitos += 1
        elif "❌ [ERROR]" in res:
            errores += 1

    end_total_time = time.time()
    print("\n--- Resumen de la Tanda ---")
    print(f"Tiempo total: {(end_total_time - start_total_time) / 60:.2f} minutos")
    print(f"Total de archivos: {len(all_root_files)}")
    print(f"Éxitos: {exitos}")
    print(f"Errores: {errores}")
    print(f"¡Listo! Tus archivos .parquet están en: {output_dir}")
# Out:
# --- INICIANDO PROCESO PARALELO (8 Workers) ---
# Buscando archivos en: /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen
# Los archivos .parquet se guardarán en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_oxigeno_17/
# Encontrados 20 archivos .root para procesar.
# Iniciando Pool con 8 trabajadores...
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run012.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run013.root► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#
#
#
#
#
#
#
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run012.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run013.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#
#
#
#
#
#
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1235
# Tiempo total de lectura: 600.49 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83271
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Lectura completa. Total de eventos leídos: 1224
# Tiempo total de lectura: 609.17 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83133
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Lectura completa. Total de eventos leídos: 1227
# Tiempo total de lectura: 617.94 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83115
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run080.rootIniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#
# Lectura completa. Total de eventos leídos: 1228
# Tiempo total de lectura: 620.07 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83286
# Lectura completa. Total de eventos leídos: 1221
# Tiempo total de lectura: 620.94 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 82578
# Lectura completa. Total de eventos leídos: 1221
# Tiempo total de lectura: 621.77 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 82983
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Lectura completa. Total de eventos leídos: 1226
# Tiempo total de lectura: 624.10 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83334
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Lectura completa. Total de eventos leídos: 1226
# Tiempo total de lectura: 625.99 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83193
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1230
# Tiempo total de lectura: 585.86 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81918
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Lectura completa. Total de eventos leídos: 1220
# Tiempo total de lectura: 587.96 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81531
# Lectura completa. Total de eventos leídos: 1225
# Tiempo total de lectura: 592.51 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81732
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Lectura completa. Total de eventos leídos: 1226
# Tiempo total de lectura: 595.02 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81564
# ► [Iniciando]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Iniciando lectura de: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Lectura completa. Total de eventos leídos: 1229
# Tiempo total de lectura: 615.15 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83109
# Lectura completa. Total de eventos leídos: 1220
# Tiempo total de lectura: 594.18 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81867
# Lectura completa. Total de eventos leídos: 1227
# Tiempo total de lectura: 616.47 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 83346
# Lectura completa. Total de eventos leídos: 1222
# Tiempo total de lectura: 607.32 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81891
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1228
# Tiempo total de lectura: 404.23 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81687
# Lectura completa. Total de eventos leídos: 1229
# Tiempo total de lectura: 398.52 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 82272
# Lectura completa. Total de eventos leídos: 1230
# Tiempo total de lectura: 409.44 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81870
# Lectura completa. Total de eventos leídos: 1224
# Tiempo total de lectura: 408.74 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 81687
#
#
# --- Proceso Paralelo Completado ---
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.parquet (643.27s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011.parquet (641.37s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run012.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run012.parquet (637.46s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run013.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run013.parquet (635.19s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.parquet (639.07s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.parquet (621.74s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.parquet (626.71s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032.parquet (638.18s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run033.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run033.parquet (616.99s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run034.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run034.parquet (618.11s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run080.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run080.parquet (594.42s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run081.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run081.parquet (587.76s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run082.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run082.parquet (590.34s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run083.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run083.parquet (596.82s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run084.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run084.parquet (609.16s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run090.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run090.parquet (595.79s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run091.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run091.parquet (405.57s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run092.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run092.parquet (410.73s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run093.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run093.parquet (410.20s)
# ✔ [Éxito]: SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run094.root -> SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run094.parquet (399.86s)
#
# --- Resumen de la Tanda ---
# Tiempo total: 27.36 minutos
# Total de archivos: 20
# Éxitos: 20
# Errores: 0
# ¡Listo! Tus archivos .parquet están en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_oxigeno_17/
#   input file   input file   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
# /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#   input file   input file   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
# /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(D.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(D.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# etector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# etector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run013Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' diffeWarning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelrs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# PointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/MWarning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/MWarning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_COalargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_COalargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update theWarning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParaRSIKA78010_FLUKA_Run013.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update theRSIKA78010_FLUKA_Run012.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    thmeterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# v version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    th version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    ths
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# e files will not be readable.
#
# e files will not be readable.
#
# e files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vWarning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParaWarning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParas
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# meterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vmeterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# s
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParaWarning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQumeterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCoantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# varianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/oxygen/SIB23e_175_180_oxygen_MdSdInfill_CORSIKA78010_FLUKA_Run094.root

# %% [markdown]
# # Paralelizacion -> Sibyl-Proton-17.5-18eV

# %%
# -----------------------------------------------------------------
# SCRIPT PRINCIPAL
# -----------------------------------------------------------------

n_workers = 8  # Ajustar como sea necesario



print(f"--- INICIANDO PROCESO PARALELO ({n_workers} Workers) ---")
start_total_time = time.time()

# --- 1. Configuración de Rutas ---
base_path = "/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton"
output_dir = "/home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_proton_17/"

os.makedirs(output_dir, exist_ok=True)
print(f"Buscando archivos en: {base_path}")
print(f"Los archivos .parquet se guardarán en: {output_dir}")

# --- 2. Encontrar todos los archivos ---
all_root_files = glob.glob(os.path.join(base_path, "*.root"))
all_root_files.sort()

if not all_root_files:
    print(f"¡Error! No se encontraron archivos .root en: {base_path}")
else:
    print(f"Encontrados {len(all_root_files)} archivos .root para procesar.")

    # --- 3. Bucle de Procesamiento Paralelo ---
    print(f"Iniciando Pool con {n_workers} trabajadores...")

    # CREAMOS LA FUNCIÓN "PARCIAL" 
    # "Congelamos" el argumento 'output_dir' de nuestra función wrapper
    process_func = partial(process_file_wrapper, output_dir=output_dir)

    with Pool(processes=n_workers) as pool:
        
        # pool.map() distribuye la lista 'all_root_files'
        # entre los 4 trabajadores y aplica la función 'process_file_wrapper'
        # results' será una lista con los strings de "Éxito" o "ERROR"
        results = pool.map(process_func, all_root_files)
    
    print("\n\n--- Proceso Paralelo Completado ---")

    # --- 4. Resumen Final ---
    exitos = 0
    errores = 0
    
    # Imprimimos todos los mensajes de resultado
    for res in results:
        print(res)
        if "✔ [Éxito]" in res:
            exitos += 1
        elif "❌ [ERROR]" in res:
            errores += 1

    end_total_time = time.time()
    print("\n--- Resumen de la Tanda ---")
    print(f"Tiempo total: {(end_total_time - start_total_time) / 60:.2f} minutos")
    print(f"Total de archivos: {len(all_root_files)}")
    print(f"Éxitos: {exitos}")
    print(f"Errores: {errores}")
    print(f"¡Listo! Tus archivos .parquet están en: {output_dir}")
# Out:
# --- INICIANDO PROCESO PARALELO (8 Workers) ---
# Buscando archivos en: /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton
# Los archivos .parquet se guardarán en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_proton_17/
# Encontrados 20 archivos .root para procesar.
# Iniciando Pool con 8 trabajadores...
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.root► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#
#
#
#
#
#
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.rootIniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.rootIniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.rootIniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.rootIniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.rootIniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.rootIniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#
#
#
#
#
#
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.... procesados 500 eventos.
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1197
# Tiempo total de lectura: 588.83 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79305
# Lectura completa. Total de eventos leídos: 1204
# Tiempo total de lectura: 590.03 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79710
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Lectura completa. Total de eventos leídos: 1197
# Tiempo total de lectura: 597.28 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79020
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Lectura completa. Total de eventos leídos: 1198
# Tiempo total de lectura: 599.47 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 78960
# Lectura completa. Total de eventos leídos: 1214
# Tiempo total de lectura: 600.29 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79953
# Lectura completa. Total de eventos leídos: 1201
# Tiempo total de lectura: 600.46 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79305
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Lectura completa. Total de eventos leídos: 1211
# Tiempo total de lectura: 605.25 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 80331
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Lectura completa. Total de eventos leídos: 1211
# Tiempo total de lectura: 611.07 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79950
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1206
# Tiempo total de lectura: 586.19 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79416
# Lectura completa. Total de eventos leídos: 1208
# Tiempo total de lectura: 590.10 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79443
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Lectura completa. Total de eventos leídos: 1210
# Tiempo total de lectura: 599.90 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79746
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Lectura completa. Total de eventos leídos: 1202
# Tiempo total de lectura: 605.27 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79749
# ► [Iniciando]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Iniciando lectura de: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Lectura completa. Total de eventos leídos: 1212
# Tiempo total de lectura: 597.37 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79488
# Lectura completa. Total de eventos leídos: 1209
# Tiempo total de lectura: 598.76 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79731
# Lectura completa. Total de eventos leídos: 1214
# Tiempo total de lectura: 605.87 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79641
# Lectura completa. Total de eventos leídos: 1210
# Tiempo total de lectura: 598.40 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79437
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1206
# Tiempo total de lectura: 388.84 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79074
# Lectura completa. Total de eventos leídos: 1207
# Tiempo total de lectura: 388.97 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79266
# Lectura completa. Total de eventos leídos: 1206
# Tiempo total de lectura: 398.24 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 78669
# Lectura completa. Total de eventos leídos: 1216
# Tiempo total de lectura: 395.06 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 79293
#
#
# --- Proceso Paralelo Completado ---
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.parquet (610.85s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.parquet (601.53s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.parquet (600.54s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.parquet (608.57s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.parquet (611.81s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.parquet (622.77s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.parquet (616.79s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.parquet (611.84s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run033.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run033.parquet (607.31s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run034.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run034.parquet (601.85s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run080.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run080.parquet (592.10s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run081.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run081.parquet (588.29s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run082.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run082.parquet (599.51s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run083.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run083.parquet (607.65s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run084.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run084.parquet (600.62s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run090.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run090.parquet (599.95s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run091.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run091.parquet (390.17s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run092.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run092.parquet (390.31s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run093.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run093.parquet (399.48s)
# ✔ [Éxito]: SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run094.root -> SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run094.parquet (396.38s)
#
# --- Resumen de la Tanda ---
# Tiempo total: 26.75 minutos
# Total de archivos: 20
# Éxitos: 20
# Errores: 0
# ¡Listo! Tus archivos .parquet están en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_sib_proton_17/
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/SIB23e/17.5_18.0/proton/SIB23e_175_180_proton_MdSdInfill_CORSIKA78010_FLUKA_Run094.root

# %% [markdown]
# # Paralelizacion -> EPOS-Helio-18-18.5eV

# %%
# -----------------------------------------------------------------
# SCRIPT PRINCIPAL
# -----------------------------------------------------------------

n_workers = 8  # Ajustar como sea necesario



print(f"--- INICIANDO PROCESO PARALELO ({n_workers} Workers) ---")
start_total_time = time.time()

# --- 1. Configuración de Rutas ---
base_path = "/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium"
output_dir = "/home/lsilva/Github/ADST_Alexey_module_v8/parquet_epos_helio_18/"

os.makedirs(output_dir, exist_ok=True)
print(f"Buscando archivos en: {base_path}")
print(f"Los archivos .parquet se guardarán en: {output_dir}")

# --- 2. Encontrar todos los archivos ---
all_root_files = glob.glob(os.path.join(base_path, "*.root"))
all_root_files.sort()

if not all_root_files:
    print(f"¡Error! No se encontraron archivos .root en: {base_path}")
else:
    print(f"Encontrados {len(all_root_files)} archivos .root para procesar.")

    # --- 3. Bucle de Procesamiento Paralelo ---
    print(f"Iniciando Pool con {n_workers} trabajadores...")

    # CREAMOS LA FUNCIÓN "PARCIAL" 
    # "Congelamos" el argumento 'output_dir' de nuestra función wrapper
    process_func = partial(process_file_wrapper, output_dir=output_dir)

    with Pool(processes=n_workers) as pool:
        
        # pool.map() distribuye la lista 'all_root_files'
        # entre los 4 trabajadores y aplica la función 'process_file_wrapper'
        # results' será una lista con los strings de "Éxito" o "ERROR"
        results = pool.map(process_func, all_root_files)
    
    print("\n\n--- Proceso Paralelo Completado ---")

    # --- 4. Resumen Final ---
    exitos = 0
    errores = 0
    
    # Imprimimos todos los mensajes de resultado
    for res in results:
        print(res)
        if "✔ [Éxito]" in res:
            exitos += 1
        elif "❌ [ERROR]" in res:
            errores += 1

    end_total_time = time.time()
    print("\n--- Resumen de la Tanda ---")
    print(f"Tiempo total: {(end_total_time - start_total_time) / 60:.2f} minutos")
    print(f"Total de archivos: {len(all_root_files)}")
    print(f"Éxitos: {exitos}")
    print(f"Errores: {errores}")
    print(f"¡Listo! Tus archivos .parquet están en: {output_dir}")
# Out:
# --- INICIANDO PROCESO PARALELO (8 Workers) ---
# Buscando archivos en: /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium
# Los archivos .parquet se guardarán en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_epos_helio_18/
# Encontrados 20 archivos .root para procesar.
# Iniciando Pool con 8 trabajadores...
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#
#
#
#
#
#
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.rootIniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.rootIniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.rootIniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.rootIniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.rootIniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.rootIniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#
#
#
#
#
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 758.19 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112218
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 764.70 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 111735
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 768.75 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112413
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 774.48 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 111618
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 780.11 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112335
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 784.98 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 111693
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root: could not convert string to float: 'R'
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 787.68 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112302
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
# Lectura completa. Total de eventos leídos: 1250Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#
# Tiempo total de lectura: 789.77 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112272
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.... procesados 1000 eventos.
#
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 748.30 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 110193
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 771.71 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112101
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 770.17 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 112650
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 771.40 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 110835
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 760.96 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 109923
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root: could not convert string to float: 'R'
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root: could not convert string to float: 'R'
# ► [Iniciando]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Iniciando lectura de: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 765.98 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 109872
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 773.88 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 110445
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root: could not convert string to float: 'R'
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root: could not convert string to float: 'R'
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 772.07 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 110871
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root: could not convert string to float: 'R'
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 500 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# ... procesados 1000 eventos.
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 521.02 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 111273
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root: could not convert string to float: 'R'
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 509.23 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 111048
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root: could not convert string to float: 'R'
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 503.04 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 110604
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root: could not convert string to float: 'R'
# Lectura completa. Total de eventos leídos: 1250
# Tiempo total de lectura: 521.51 segundos.
# Total de 'MÓDULOS' (filas) extraídos: 111039
#   Advertencia: No se pudo parsear metadata en EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root: could not convert string to float: 'R'
#
#
# --- Proceso Paralelo Completado ---
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.parquet (776.18s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.parquet (780.25s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.parquet (796.64s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.parquet (769.56s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.parquet (785.72s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.parquet (791.28s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.parquet (801.06s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.parquet (798.65s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.parquet (774.76s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.parquet (772.98s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.parquet (750.82s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.parquet (774.04s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.parquet (776.04s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.parquet (763.52s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.parquet (768.24s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.parquet (773.96s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.parquet (523.17s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.parquet (523.20s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.parquet (511.03s)
# ✔ [Éxito]: EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root -> EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.parquet (504.89s)
#
# --- Resumen de la Tanda ---
# Tiempo total: 34.47 minutos
# Total de archivos: 20
# Éxitos: 20
# Errores: 0
# ¡Listo! Tus archivos .parquet están en: /home/lsilva/Github/ADST_Alexey_module_v8/parquet_epos_helio_18/
#   input file   input file   input file   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root/srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#
#
#
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run032.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run013.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run031.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run012.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run011.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run030.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run014.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Detector read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=27) as the active class but a different checksum.
#    You should update the version to ClassDef(Detector,28).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 27 of class 'Detector' differs from
# the in-memory layout version 27:
#    map<int,EyePointingIdMap> fTelPointingIds; //
# vs
#    map<int,map<int,TString> > fTelPointingIds; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class RdRecStationParameterStorageMap read from file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run010.root
#    has the same version (=7) as the active class but a different checksum.
#    You should update the version to ClassDef(RdRecStationParameterStorageMap,8).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<revt::ShowerRRecDataQuantities,double> fParameterMap; //
# vs
#    map<revt::StationRRecDataQuantities,double> fParameterMap; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 7 of class 'RdRecStationParameterStorageMap' differs from
# the in-memory layout version 7:
#    map<pair<revt::ShowerRRecDataQuantities,revt::ShowerRRecDataQuantities>,double> fCovarianceMap; //
# vs
#    map<pair<revt::StationRRecDataQuantities,revt::StationRRecDataQuantities>,double> fCovarianceMap; //
# Warning in <TClass::Init>: no dictionary for class MdSimScintillator::Particle is available
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
# Warning in <TStreamerInfo::BuildOld>: Cannot convert Detector::fTelPointingIds from type: map<int,EyePointingIdMap> to type: map<int,map<int,TString> >, skip element
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run033.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run034.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run080.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run081.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run082.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run083.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run084.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run090.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run091.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run092.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run093.root
#   input file /srv/data/Malargue/icrc2025/test7/IdealMC_CORSIKA/MdSdInfill_CORSIKA78010_FLUKA/EPOSLHC_R/18.0_18.5/helium/EPOSLHC_R_180_185_helium_MdSdInfill_CORSIKA78010_FLUKA_Run094.root
