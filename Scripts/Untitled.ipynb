# %%
def f(p, h):
    if p>h:
        nota = 24.5+10.5*(p-h)/(10-h)
    else:
        nota = 24.5*(p-4)/(h-4)
    return nota

# %% [markdown]
# con el promedio historico que esta en la pagina de la uba

# %% [markdown]
# - con mi prom actual

# %%
print(f(8.714, 8.86))
# Out:
# 23.76399176954733

# %% [markdown]
# - con el promedio de si tengo 10 en teo 2, 3 y calculo

# %%
print(f(8.875, 8.86))
# Out:
# 24.638157894736846

# %% [markdown]
# con el promedio historico que aparece en la convocatoria de conicet de 2023

# %% [markdown]
# - con mi prom actual

# %%
print(f(8.714, 8.61))
# Out:
# 25.285611510791373

# %% [markdown]
# - con el promedio de si tengo 10 en teo 2, 3 y calculo

# %%
print(f(8.875, 8.61))
# Out:
# 26.501798561151084
