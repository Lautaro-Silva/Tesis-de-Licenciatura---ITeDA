# %%
def f(p, h):
    if p>h:
        nota = 24.5+10.5*(p-h)/(10-h)
    else:
        nota = 24.5*(p-4)/(h-4)
    return nota

# %% [markdown]
# # con el promedio historico que esta en la pagina de la uba -> 8.86

# %% [markdown]
# - con mi prom actual (todo salvo M2) -> realista

# %%
print(f(8.727, 8.86))
# Out:
# 23.829526748971197

# %% [markdown]
# - con mi prom actual (todo salvo M2) + tengo 10 en teo2 y 3

# %%
print(f(8.833, 8.86))
# Out:
# 24.363888888888894

# %% [markdown]
# - con el promedio si puedo volar E3 -> ideal

# %%
print(f(8.857, 8.86))
# Out:
# 24.484876543209875

# %% [markdown]
# - con el promedio ideal de arriba + tengo 10 en teo 2, 3

# %%
print(f(8.957, 8.86))
# Out:
# 25.39342105263159

# %% [markdown]
# # con el promedio historico que aparece en la convocatoria de conicet de 2023-2024-> 8.61

# %% [markdown]
# - con mi prom actual (todo salvo M2) -> realista

# %%
print(f(8.727, 8.61))
# Out:
# 25.383812949640294

# %% [markdown]
# - con mi prom actual (todo salvo M2) + tengo 10 en teo2 y 3

# %%
print(f(8.833, 8.61))
# Out:
# 26.184532374100723

# %% [markdown]
# - con el promedio si puedo volar E3 -> ideal

# %%
print(f(8.857, 8.61))
# Out:
# 26.365827338129495

# %% [markdown]
# - con el promedio ideal de arriba + tengo 10 en teo 2, 3

# %%
print(f(8.957, 8.61))
# Out:
# 27.121223021582743

# %%
print(f(8.96, 8.13))
# Out:
# 29.160427807486634
